# %% [markdown]
# <a href="https://colab.research.google.com/github/somaananta/learn_AI_with_som/blob/main/end_to_end_ml.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/content/placement.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
df.shape
# Out:
# (100, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  100 non-null    int64
#  1   cgpa        100 non-null    float64
#  2   iq          100 non-null    float64
#  3   placement   100 non-null    int64
# dtypes: float64(2), int64(2)
# memory usage: 3.3 KB

# %%
df=df.iloc[:,1:]

# %%
df.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['cgpa'],df['iq'],c=df['placement'])

# %%
x=df.iloc[:,0:2]
y=df.iloc[:,-1]

# %%
x
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
y
# Out:
# 0     1
# 1     0
# 2     0
# 3     1
# 4     0
#      ..
# 95    0
# 96    0
# 97    1
# 98    1
# 99    1
# Name: placement, Length: 100, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.1)

# %%
x_train
# Out:
#     cgpa     iq
# 64   7.0   64.0
# 81   5.4  107.0
# 25   5.0   91.0
# 10   6.0   45.0
# 54   6.4  141.0
# ..   ...    ...
# 70   6.3  127.0
# 95   4.3  200.0
# 88   4.4  149.0
# 15   5.1  176.0
# 14   6.1  103.0
#
# [90 rows x 2 columns]

# %%
y_train
# Out:
# 64    1
# 81    0
# 25    0
# 10    1
# 54    1
#      ..
# 70    1
# 95    0
# 88    0
# 15    0
# 14    0
# Name: placement, Length: 90, dtype: int64

# %%
x_test
# Out:
#     cgpa     iq
# 35   6.8   90.0
# 17   3.3  183.0
# 63   6.3  128.0
# 42   7.6   89.0
# 52   7.0  175.0
# 78   6.1   81.0
# 9    5.1   66.0
# 2    5.3  121.0
# 19   5.2  132.0
# 55   7.8  114.0

# %%
y_test
# Out:
# 35    1
# 17    0
# 63    1
# 42    1
# 52    1
# 78    0
# 9     0
# 2     0
# 19    0
# 55    1
# Name: placement, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)

# %%
x_train
# Out:
# array([[ 0.90754132, -1.50471889],
#        [-0.52228308, -0.43011802],
#        [-0.87973918, -0.82996951],
#        [ 0.01390107, -1.97954254],
#        [ 0.37135717,  0.41956639],
#        [ 0.37135717, -0.20520156],
#        [ 1.8905456 ,  0.61949213],
#        [ 1.35436145,  0.84440859],
#        [ 0.19262912, -0.28017372],
#        [ 1.35436145,  0.14466849],
#        [ 0.1032651 ,  0.19464993],
#        [ 0.55008522, -0.10523869],
#        [-1.23719528,  0.54451998],
#        [-0.254191  ,  0.39457567],
#        [ 0.99690535, -1.90457038],
#        [ 0.01390107, -0.00527582],
#        [-0.254191  ,  0.46954782],
#        [ 0.72881327, -0.03026654],
#        [-0.254191  ,  1.11930649],
#        [-0.87973918, -0.15522013],
#        [ 0.90754132,  0.36958495],
#        [ 0.01390107,  0.61949213],
#        [-0.96910321, -1.57969105],
#        [-2.22019956,  2.71871244],
#        [ 1.1756334 , -0.20520156],
#        [ 0.01390107, -0.55507161],
#        [ 0.72881327,  0.41956639],
#        [-1.14783126, -1.80460751],
#        [ 0.4607212 ,  0.89439003],
#        [ 0.63944925,  0.74444572],
#        [-1.77337943, -1.229821  ],
#        [-0.70101113,  2.49379598],
#        [ 1.35436145, -1.57969105],
#        [-1.77337943, -0.60505305],
#        [ 0.28199315, -0.5300809 ],
#        [ 1.1756334 , -1.85458895],
#        [-0.96910321,  0.76943644],
#        [ 0.1032651 , -1.47972818],
#        [-1.05846723,  0.41956639],
#        [-1.86274346, -0.38013659],
#        [ 1.8905456 ,  1.04433434],
#        [ 0.72881327, -0.30516443],
#        [ 0.4607212 , -0.85496023],
#        [-0.70101113, -0.85496023],
#        [-1.41592333, -2.05451469],
#        [-1.05846723,  0.96936218],
#        [ 1.44372547,  0.09468705],
#        [-0.70101113,  0.91938075],
#        [ 0.01390107, -1.45473746],
#        [ 2.06927365,  1.09431577],
#        [-1.14783126, -0.08024797],
#        [ 1.80118157, -1.12985813],
#        [ 0.8181773 ,  0.34459423],
#        [-0.61164711, -0.255183  ],
#        [ 0.90754132, -0.30516443],
#        [-1.05846723, -0.30516443],
#        [-0.07546295, -0.45510874],
#        [-0.16482698,  1.04433434],
#        [ 2.2480017 , -0.10523869],
#        [ 0.8181773 , -0.70501592],
#        [-0.87973918, -1.52970961],
#        [-0.79037516,  0.09468705],
#        [ 0.90754132,  1.86902803],
#        [ 1.1756334 , -0.9549231 ],
#        [ 0.8181773 ,  0.36958495],
#        [ 0.55008522,  0.34459423],
#        [-0.96910321, -0.10523869],
#        [ 0.1032651 ,  0.79442716],
#        [-0.96910321,  0.66947357],
#        [ 0.99690535,  0.66947357],
#        [-0.96910321,  0.24463136],
#        [-0.52228308, -0.255183  ],
#        [ 1.26499742,  0.19464993],
#        [ 0.4607212 ,  0.14466849],
#        [-1.14783126, -0.92993238],
#        [-0.70101113, -0.35514587],
#        [-0.52228308,  0.36958495],
#        [ 1.1756334 ,  0.31960352],
#        [-0.52228308,  0.26962208],
#        [-1.05846723,  1.11930649],
#        [ 0.4607212 , -2.17946828],
#        [ 0.63944925,  1.44418582],
#        [-0.16482698,  0.4445571 ],
#        [-0.96910321,  1.79405587],
#        [-0.254191  ,  0.19464993],
#        [ 0.28199315,  0.06969634],
#        [-1.50528736,  1.89401875],
#        [-1.41592333,  0.61949213],
#        [-0.79037516,  1.29424151],
#        [ 0.1032651 , -0.5300809 ]])

# %%
x_test = scaler.transform(x_test)

# %%
x_test
# Out:
# array([[ 0.72881327, -0.85496023],
#        [-2.39892761,  1.46917654],
#        [ 0.28199315,  0.09468705],
#        [ 1.44372547, -0.87995095],
#        [ 0.90754132,  1.2692508 ],
#        [ 0.1032651 , -1.07987669],
#        [-0.79037516, -1.45473746],
#        [-0.61164711, -0.08024797],
#        [-0.70101113,  0.19464993],
#        [ 1.62245352, -0.255183  ]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression()

# %%
#model training
clf.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=clf.predict(x_test)

# %%
y_test
# Out:
# 35    1
# 17    0
# 63    1
# 42    1
# 52    1
# 78    0
# 9     0
# 2     0
# 19    0
# 55    1
# Name: placement, dtype: int64

# %%
from sklearn.metrics import accuracy_score

# %%
scr=accuracy_score(y_test,y_pred)

# %%
scr
# Out:
# 0.9

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x_train,y_train.values,clf=clf,legend=2)
# Out:
# <Axes: >

# %%
import pickle

# %%
pickle.dump(clf,open('model.pkl','wb'))
