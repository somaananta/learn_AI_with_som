# %% [markdown]
# <a href="https://colab.research.google.com/github/somaananta/learn_AI_with_som/blob/main/iplanalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv('/content/sample_data/matches.csv')

# %%
data
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.head(3)
# Out:
#    id  season       city        date                team1  \
# 0   1    2017  Hyderabad  2017-04-05  Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06       Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07        Gujarat Lions
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
#
#    result  dl_applied                  winner  win_by_runs  win_by_wickets  \
# 0  normal           0     Sunrisers Hyderabad           35               0
# 1  normal           0  Rising Pune Supergiant            0               7
# 2  normal           0   Kolkata Knight Riders            0              10
#
#   player_of_match                                      venue         umpire1  \
# ...

# %%
data.tail(3)
# Out:
#       id  season       city        date                team1  \
# 633  634    2016      Delhi  2016-05-25  Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27        Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29  Sunrisers Hyderabad
#
#                            team2            toss_winner toss_decision  result  \
# 633        Kolkata Knight Riders  Kolkata Knight Riders         field  normal
# 634          Sunrisers Hyderabad    Sunrisers Hyderabad         field  normal
# 635  Royal Challengers Bangalore    Sunrisers Hyderabad           bat  normal
#
#      dl_applied               winner  win_by_runs  win_by_wickets  \
# 633           0  Sunrisers Hyderabad           22               0
# 634           0  Sunrisers Hyderabad            0               4
# 635           0  Sunrisers Hyderabad            8               0
#
#     player_of_match                  venue          umpire1        umpire2  \
# ...

# %%
data.shape
# Out:
# (636, 18)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636 entries, 0 to 635
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               636 non-null    int64
#  1   season           636 non-null    int64
#  2   city             629 non-null    object
#  3   date             636 non-null    object
#  4   team1            636 non-null    object
#  5   team2            636 non-null    object
#  6   toss_winner      636 non-null    object
#  7   toss_decision    636 non-null    object
#  8   result           636 non-null    object
#  9   dl_applied       636 non-null    int64
#  10  winner           633 non-null    object
#  11  win_by_runs      636 non-null    int64
#  12  win_by_wickets   636 non-null    int64
#  13  player_of_match  633 non-null    object
#  14  venue            636 non-null    object
#  15  umpire1          635 non-null    object
#  16  umpire2          635 non-null    object
# ...

# %%
data.describe()
# Out:
#                id       season  dl_applied  win_by_runs  win_by_wickets  \
# count  636.000000   636.000000  636.000000   636.000000      636.000000
# mean   318.500000  2012.490566    0.025157    13.682390        3.372642
# std    183.741666     2.773026    0.156726    23.908877        3.420338
# min      1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%    159.750000  2010.000000    0.000000     0.000000        0.000000
# 50%    318.500000  2012.000000    0.000000     0.000000        4.000000
# 75%    477.250000  2015.000000    0.000000    20.000000        7.000000
# max    636.000000  2017.000000    1.000000   146.000000       10.000000
#
#        umpire3
# count      0.0
# mean       NaN
# std        NaN
# min        NaN
# 25%        NaN
# 50%        NaN
# 75%        NaN
# max        NaN

# %%
data["winner"]
# Out:
# 0              Sunrisers Hyderabad
# 1           Rising Pune Supergiant
# 2            Kolkata Knight Riders
# 3                  Kings XI Punjab
# 4      Royal Challengers Bangalore
#                   ...
# 631    Royal Challengers Bangalore
# 632    Royal Challengers Bangalore
# 633            Sunrisers Hyderabad
# 634            Sunrisers Hyderabad
# 635            Sunrisers Hyderabad
# Name: winner, Length: 636, dtype: object

# %%
data[['city','winner']]
# Out:
#           city                       winner
# 0    Hyderabad          Sunrisers Hyderabad
# 1         Pune       Rising Pune Supergiant
# 2       Rajkot        Kolkata Knight Riders
# 3       Indore              Kings XI Punjab
# 4    Bangalore  Royal Challengers Bangalore
# ..         ...                          ...
# 631     Raipur  Royal Challengers Bangalore
# 632  Bangalore  Royal Challengers Bangalore
# 633      Delhi          Sunrisers Hyderabad
# 634      Delhi          Sunrisers Hyderabad
# 635  Bangalore          Sunrisers Hyderabad
#
# [636 rows x 2 columns]

# %%
data.iloc[[1,3]]
# Out:
#    id  season    city        date                   team1  \
# 1   2    2017    Pune  2017-04-06          Mumbai Indians
# 3   4    2017  Indore  2017-04-08  Rising Pune Supergiant
#
#                     team2             toss_winner toss_decision  result  \
# 1  Rising Pune Supergiant  Rising Pune Supergiant         field  normal
# 3         Kings XI Punjab         Kings XI Punjab         field  normal
#
#    dl_applied                  winner  win_by_runs  win_by_wickets  \
# 1           0  Rising Pune Supergiant            0               7
# 3           0         Kings XI Punjab            0               6
#
#   player_of_match                                    venue         umpire1  \
# 1       SPD Smith  Maharashtra Cricket Association Stadium  A Nand Kishore
# 3      GJ Maxwell                   Holkar Cricket Stadium    AK Chaudhary
#
#          umpire2  umpire3
# 1         S Ravi      NaN
# 3  C Shamshuddin      NaN

# %%
data.iloc[3]
# Out:
# id                                      4
# season                               2017
# city                               Indore
# date                           2017-04-08
# team1              Rising Pune Supergiant
# team2                     Kings XI Punjab
# toss_winner               Kings XI Punjab
# toss_decision                       field
# result                             normal
# dl_applied                              0
# winner                    Kings XI Punjab
# win_by_runs                             0
# win_by_wickets                          6
# player_of_match                GJ Maxwell
# venue              Holkar Cricket Stadium
# umpire1                      AK Chaudhary
# umpire2                     C Shamshuddin
# umpire3                               NaN
# Name: 3, dtype: object

# %%
data.iloc[1:4]
# Out:
#    id  season    city        date                   team1  \
# 1   2    2017    Pune  2017-04-06          Mumbai Indians
# 2   3    2017  Rajkot  2017-04-07           Gujarat Lions
# 3   4    2017  Indore  2017-04-08  Rising Pune Supergiant
#
#                     team2             toss_winner toss_decision  result  \
# 1  Rising Pune Supergiant  Rising Pune Supergiant         field  normal
# 2   Kolkata Knight Riders   Kolkata Knight Riders         field  normal
# 3         Kings XI Punjab         Kings XI Punjab         field  normal
#
#    dl_applied                  winner  win_by_runs  win_by_wickets  \
# 1           0  Rising Pune Supergiant            0               7
# 2           0   Kolkata Knight Riders            0              10
# 3           0         Kings XI Punjab            0               6
#
#   player_of_match                                    venue         umpire1  \
# 1       SPD Smith  Maharashtra Cricket Association Stadium  A Nand Kishore
# ...

# %%
data.iloc[1:30:2]
# Out:
#     id  season       city        date                        team1  \
# 1    2    2017       Pune  2017-04-06               Mumbai Indians
# 3    4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 5    6    2017  Hyderabad  2017-04-09                Gujarat Lions
# 7    8    2017     Indore  2017-04-10  Royal Challengers Bangalore
# 9   10    2017     Mumbai  2017-04-12          Sunrisers Hyderabad
# 11  12    2017  Bangalore  2017-04-14  Royal Challengers Bangalore
# 13  14    2017    Kolkata  2017-04-15        Kolkata Knight Riders
# 15  16    2017     Mumbai  2017-04-16                Gujarat Lions
# 17  18    2017      Delhi  2017-04-17             Delhi Daredevils
# 19  20    2017     Rajkot  2017-04-18  Royal Challengers Bangalore
# 21  22    2017     Indore  2017-04-20              Kings XI Punjab
# 23  24    2017     Mumbai  2017-04-22               Mumbai Indians
# 25  26    2017     Rajkot  2017-04-23              Kings XI Punjab
# ...

# %%
data.iloc[[2,6,11,54]]
# Out:
#     id  season       city        date                        team1  \
# 2    3    2017     Rajkot  2017-04-07                Gujarat Lions
# 6    7    2017     Mumbai  2017-04-09        Kolkata Knight Riders
# 11  12    2017  Bangalore  2017-04-14  Royal Challengers Bangalore
# 54  55    2017      Delhi  2017-05-14  Royal Challengers Bangalore
#
#                     team2                  toss_winner toss_decision  result  \
# 2   Kolkata Knight Riders        Kolkata Knight Riders         field  normal
# 6          Mumbai Indians               Mumbai Indians         field  normal
# 11         Mumbai Indians               Mumbai Indians         field  normal
# 54       Delhi Daredevils  Royal Challengers Bangalore           bat  normal
#
#     dl_applied                       winner  win_by_runs  win_by_wickets  \
# 2            0        Kolkata Knight Riders            0              10
# 6            0               Mumbai Indians            0               4
# ...

# %%
data.iloc[:,[4,5,13]]
# Out:
#                            team1                        team2 player_of_match
# 0            Sunrisers Hyderabad  Royal Challengers Bangalore    Yuvraj Singh
# 1                 Mumbai Indians       Rising Pune Supergiant       SPD Smith
# 2                  Gujarat Lions        Kolkata Knight Riders         CA Lynn
# 3         Rising Pune Supergiant              Kings XI Punjab      GJ Maxwell
# 4    Royal Challengers Bangalore             Delhi Daredevils       KM Jadhav
# ..                           ...                          ...             ...
# 631             Delhi Daredevils  Royal Challengers Bangalore         V Kohli
# 632                Gujarat Lions  Royal Challengers Bangalore  AB de Villiers
# 633          Sunrisers Hyderabad        Kolkata Knight Riders    MC Henriques
# 634                Gujarat Lions          Sunrisers Hyderabad       DA Warner
# 635          Sunrisers Hyderabad  Royal Challengers Bangalore     BCJ Cutting
#
# [636 rows x 3 columns]

# %%
data.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
mask=data['city']=='Hyderabad'

# %%
mask
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 631    False
# 632    False
# 633    False
# 634    False
# 635    False
# Name: city, Length: 636, dtype: bool

# %%
data[mask]
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 5      6    2017  Hyderabad  2017-04-09                Gujarat Lions
# 18    19    2017  Hyderabad  2017-04-17          Sunrisers Hyderabad
# 20    21    2017  Hyderabad  2017-04-19          Sunrisers Hyderabad
# 35    36    2017  Hyderabad  2017-04-30          Sunrisers Hyderabad
# 42    43    2017  Hyderabad  2017-05-06       Rising Pune Supergiant
# 46    47    2017  Hyderabad  2017-05-08               Mumbai Indians
# 58    59    2017  Hyderabad  2017-05-21               Mumbai Indians
# 65    66    2008  Hyderabad  2008-04-22              Deccan Chargers
# 67    68    2008  Hyderabad  2008-04-24              Deccan Chargers
# 76    77    2008  Hyderabad  2008-05-01              Deccan Chargers
# 79    80    2008  Hyderabad  2008-05-25              Deccan Chargers
# 91    92    2008  Hyderabad  2008-05-11        Kolkata Knight Riders
# ...

# %%
def get_city_match_count(city):
  mask=data['city']==city
  return data[mask].shape[0]

# %%
get_city_match_count('Hyderabad')
# Out:
# 49

# %%
data.head(3)
# Out:
#    id  season       city        date                team1  \
# 0   1    2017  Hyderabad  2017-04-05  Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06       Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07        Gujarat Lions
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
#
#    result  dl_applied                  winner  win_by_runs  win_by_wickets  \
# 0  normal           0     Sunrisers Hyderabad           35               0
# 1  normal           0  Rising Pune Supergiant            0               7
# 2  normal           0   Kolkata Knight Riders            0              10
#
#   player_of_match                                      venue         umpire1  \
# ...

# %%
def get_city_match_count(city,season):
  mask=(data['city']==city) & (data['season']>season)
  return data[mask].shape[0]

# %%
get_city_match_count('Hyderabad',2010)
# Out:
# 42

# %%
data['winner'].value_counts()
# Out:
# winner
# Mumbai Indians                 92
# Chennai Super Kings            79
# Kolkata Knight Riders          77
# Royal Challengers Bangalore    73
# Kings XI Punjab                70
# Rajasthan Royals               63
# Delhi Daredevils               62
# Sunrisers Hyderabad            42
# Deccan Chargers                29
# Gujarat Lions                  13
# Pune Warriors                  12
# Rising Pune Supergiant         10
# Kochi Tuskers Kerala            6
# Rising Pune Supergiants         5
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
data['winner'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='winner'>

# %%
data['winner'].value_counts().head(5).plot(kind='bar')
# Out:
# <Axes: xlabel='winner'>

# %%
data['winner'].value_counts().head(7).plot(kind='barh')
# Out:
# <Axes: ylabel='winner'>

# %%
data['toss_decision'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
data['win_by_runs'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
myseriese=data['winner'].value_counts()

# %%
myseriese.index
# Out:
# Index(['Mumbai Indians', 'Chennai Super Kings', 'Kolkata Knight Riders',
#        'Royal Challengers Bangalore', 'Kings XI Punjab', 'Rajasthan Royals',
#        'Delhi Daredevils', 'Sunrisers Hyderabad', 'Deccan Chargers',
#        'Gujarat Lions', 'Pune Warriors', 'Rising Pune Supergiant',
#        'Kochi Tuskers Kerala', 'Rising Pune Supergiants'],
#       dtype='object', name='winner')

# %%
myseriese.index.size
# Out:
# 14

# %%
myseriese.index[1]
# Out:
# 'Chennai Super Kings'

# %%
myseriese.values
# Out:
# array([92, 79, 77, 73, 70, 63, 62, 42, 29, 13, 12, 10,  6,  5])

# %%
myseriese.head()
# Out:
# winner
# Mumbai Indians                 92
# Chennai Super Kings            79
# Kolkata Knight Riders          77
# Royal Challengers Bangalore    73
# Kings XI Punjab                70
# Name: count, dtype: int64

# %%
myseriese.tail()
# Out:
# winner
# Gujarat Lions              13
# Pune Warriors              12
# Rising Pune Supergiant     10
# Kochi Tuskers Kerala        6
# Rising Pune Supergiants     5
# Name: count, dtype: int64

# %%
myseriese['Rising Pune Supergiant']
# Out:
# 10

# %%
#Find all matches played by Mumbai indians in Team1 and Team2
total_matches=data['team1'].value_counts() + data['team2'].value_counts()

# %%
total_matches.sort_values(ascending=False)
# Out:
# Mumbai Indians                 157
# Royal Challengers Bangalore    152
# Kings XI Punjab                148
# Kolkata Knight Riders          148
# Delhi Daredevils               147
# Chennai Super Kings            131
# Rajasthan Royals               118
# Sunrisers Hyderabad             76
# Deccan Chargers                 75
# Pune Warriors                   46
# Gujarat Lions                   30
# Rising Pune Supergiant          16
# Kochi Tuskers Kerala            14
# Rising Pune Supergiants         14
# Name: count, dtype: int64
