# %% [markdown]
# <a href="https://colab.research.google.com/github/somaananta/learn_AI_with_som/blob/main/work_with_json.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
pd.read_json("/content/train.json")
# Out:
#           id      cuisine                                        ingredients
# 0      10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1      25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2      20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3      22213       indian                [water, vegetable oil, wheat, salt]
# 4      13162       indian  [black pepper, shallots, cornflour, cayenne pe...
# ...      ...          ...                                                ...
# 39769  29109        irish  [light brown sugar, granulated sugar, butter, ...
# 39770  11462      italian  [KRAFT Zesty Italian Dressing, purple onion, b...
# 39771   2238        irish  [eggs, citrus fruit, raisins, sourdough starte...
# 39772  41882      chinese  [boneless chicken skinless thigh, minced garli...
# 39773   2362      mexican  [green chile, jalapeno chilies, onions, ground...
#
# [39774 rows x 3 columns]

# %%
pd.read_json("https://api.exchangerate-api.com/v4/latest/INR")
# Out:
#                              provider  \
# INR  https://www.exchangerate-api.com
# AED  https://www.exchangerate-api.com
# AFN  https://www.exchangerate-api.com
# ALL  https://www.exchangerate-api.com
# AMD  https://www.exchangerate-api.com
# ..                                ...
# XPF  https://www.exchangerate-api.com
# YER  https://www.exchangerate-api.com
# ZAR  https://www.exchangerate-api.com
# ZMW  https://www.exchangerate-api.com
# ZWL  https://www.exchangerate-api.com
#
#                           WARNING_UPGRADE_TO_V6  \
# INR  https://www.exchangerate-api.com/docs/free
# AED  https://www.exchangerate-api.com/docs/free
# AFN  https://www.exchangerate-api.com/docs/free
# ALL  https://www.exchangerate-api.com/docs/free
# AMD  https://www.exchangerate-api.com/docs/free
# ..                                          ...
# XPF  https://www.exchangerate-api.com/docs/free
# YER  https://www.exchangerate-api.com/docs/free
# ZAR  https://www.exchangerate-api.com/docs/free
# ...

# %% [markdown]
# #Working with SQL

# %%
pip install mysql.connector
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.9/11.9 MB 64.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for mysql.connector: filename=mysql_connector-2.2.9-cp311-cp311-linux_x86_64.whl size=247951 sha256=d867d1d4480d35d449b8bc7c09597e170593153d1fb00158dbcee308ee5a49fd
#   Stored in directory: /root/.cache/pip/wheels/17/cd/ed/2d49e9bac69cf09382e4c7cc20a2511202b48324b87db26019
# Successfully built mysql.connector
# ...

# %%
import mysql.connector

# %%
mysql.connector.connect(host="192.168.174.1", user="som",password="",database="world")
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/mysql/connector/network.py in open_connection(self)
#     794             self.sock.settimeout(self._connection_timeout)
# --> 795             self.sock.connect(sockaddr)
#     796         except (socket.timeout, TimeoutError) as err:
#
# TimeoutError: [Errno 110] Connection timed out
#
# The above exception was the direct cause of the following exception:
#
# ConnectionTimeoutError                    Traceback (most recent call last)
# /tmp/ipython-input-7-2223769938.py in <cell line: 0>()
# ----> 1 mysql.connector.connect(host="192.168.174.1", user="som",password="",database="world")
#
# /usr/local/lib/python3.11/dist-packages/mysql/connector/pooling.py in connect(*args, **kwargs)
#     321     if CMySQLConnection and not use_pure:
# ...

# %%
import pandas as pd
import requests

# %%
response = requests.get("https://api.themoviedb.org/3/movie/top_rated?api_key=67d5e2ada316defacf9d3c4f5d60cd2c&&language=en-US&page=1")

# %%
#pd.DataFrame(response.json()["results"]).head(2)
df=pd.DataFrame(response.json()["results"])[['id','original_title','overview','release_date','popularity','vote_average','vote_count']]

# %%
df
# Out:
#         id                                 original_title  \
# 0      278                       The Shawshank Redemption
# 1      238                                  The Godfather
# 2   803796                             KPop Demon Hunters
# 3      240                          The Godfather Part II
# 4      424                               Schindler's List
# 5      389                                   12 Angry Men
# 6      129                                       千と千尋の神隠し
# 7      155                                The Dark Knight
# 8    19404                   दिलवाले दुल्हनिया ले जायेंगे
# 9      497                                 The Green Mile
# 10  496243                                            기생충
# 11     680                                   Pulp Fiction
# 12     122  The Lord of the Rings: The Return of the King
# 13  372058                                          君の名は。
# 14      13                                   Forrest Gump
# ...

# %%
df = pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(1,501):
  response = requests.get("https://api.themoviedb.org/3/movie/top_rated?api_key=67d5e2ada316defacf9d3c4f5d60cd2c&&language=en-US&page={}".format(i))
  temp_df = pd.DataFrame(response.json()["results"])[['id','original_title','overview','release_date','popularity','vote_average','vote_count']]
  df= pd.concat([df,temp_df],ignore_index=True)

# %%
df
# Out:
#            id            original_title  \
# 0         278  The Shawshank Redemption
# 1         238             The Godfather
# 2      803796        KPop Demon Hunters
# 3         240     The Godfather Part II
# 4         424          Schindler's List
# ...       ...                       ...
# 69995  254474                Zombeavers
# 69996   68637            L'Élève Ducobu
# 69997   42436        Natale in crociera
# 69998  329833               Zoolander 2
# 69999   10384                 Supernova
#
#                                                 overview release_date  \
# 0      Imprisoned in the 1940s for the double murder ...   1994-09-23
# 1      Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 2      When K-pop superstars Rumi, Mira and Zoey aren...   2025-06-20
# 3      In the continuing saga of the Corleone crime f...   1974-12-20
# 4      The true story of how businessman Oskar Schind...   1993-12-15
# ...

# %%
df.shape
# Out:
# (70000, 7)

# %%
df.to_csv('movies2.csv')
